# %%
import preprocessing as PRE
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
train, test = PRE.preprocess(PATH='Data/Raw/', frac=0.1, outliers=False)

# %%
# SalePrice
f = plt.figure(figsize=(20, 5))

ax = f.add_subplot(121, title='SalePrice')
sns.distplot(train.SalePrice)

ax = f.add_subplot(122, title='Log(SalePrice)')
sns.distplot(np.log(train.SalePrice))

plt.show()

# %%
# %timeit np.log(train.SalePrice)
# Out:
# 91.1 µs ± 2.66 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit np.log(train['SalePrice'])
# Out:
# 86.5 µs ± 5.83 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
